# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import plotly.express as px

# %%
Estres = pd.read_excel("datos_estres_1.xlsx")
Estres
# Out:
#       Folio         ID Levantada por              Municipio       CP  \
# 0         1  208841844          IIEG            Tlaquepaque  45608.0
# 1         2  208843594          IIEG            Guadalajara  44630.0
# 2         3  208844050          IIEG        Puerto Vallarta  48333.0
# 3         5  208844264          IIEG            Guadalajara  44890.0
# 4         7  208845188          IIEG        Lagos de Moreno  47420.0
# 5         8  208845282          IIEG        Puerto Vallarta  48295.0
# 6        10  208845450          IIEG            Guadalajara  44600.0
# 7        11  208845488          IIEG            Guadalajara  44100.0
# 8        12  208845575          IIEG                Zapopan  45059.0
# 9        15  208846087          IIEG            Guadalajara  44860.0
# 10       18  208846473          IIEG        No especificado      NaN
# 11       19  208846671          IIEG            Guadalajara  44360.0
# 12       20  208846749          IIEG            Guadalajara  44100.0
# ...

# %%
Estres.describe()
# Out:
#              Folio            ID            CP  tiempo_operacion  \
# count  1992.000000  1.992000e+03   1916.000000       1992.000000
# mean    996.500000  2.089632e+08  45546.110647         14.134036
# std     575.185188  5.435501e+04   1548.626439         12.647626
# min       1.000000  2.088418e+08  25122.000000          0.000000
# 25%     498.750000  2.089254e+08  44600.000000          5.000000
# 50%     996.500000  2.089568e+08  45050.000000         10.000000
# 75%    1494.250000  2.090141e+08  45662.250000         20.000000
# max    1992.000000  2.090471e+08  59455.000000        118.000000
#
#        provedores_nacionales  ventas_porcentaje  perdidas_porcentaje  \
# count            1992.000000        1992.000000          1992.000000
# mean              109.006024         138.290161           138.906627
# std               141.507326         243.728584           256.924388
# min                 0.000000           0.000000             3.000000
# ...

# %%
Estres.describe()
# Out:
#              Folio            ID            CP  tiempo_operacion  \
# count  1992.000000  1.992000e+03   1916.000000       1992.000000
# mean    996.500000  2.089632e+08  45546.110647         14.134036
# std     575.185188  5.435501e+04   1548.626439         12.647626
# min       1.000000  2.088418e+08  25122.000000          0.000000
# 25%     498.750000  2.089254e+08  44600.000000          5.000000
# 50%     996.500000  2.089568e+08  45050.000000         10.000000
# 75%    1494.250000  2.090141e+08  45662.250000         20.000000
# max    1992.000000  2.090471e+08  59455.000000        118.000000
#
#        provedores_nacionales  ventas_porcentaje  perdidas_porcentaje  \
# count            1992.000000        1992.000000          1992.000000
# mean              109.006024         138.290161           138.906627
# std               141.507326         243.728584           256.924388
# min                 0.000000           0.000000             3.000000
# ...

# %%
Stress = Estres['Estrés'].value_counts()

# %%
Estres_sector = Estres.groupby('Sector') 
Comercio.get_group('Comercio') 
Estres_sector = Comercio['Estrés']
Estres_sector_median = Estres_sector.median()
Estres_sector_median
# Out:
# Sector
# Comercio        28
# Construcción    28
# Manufactura     28
# Servicios       26
# Name: Estrés, dtype: int64

# %%
Estres_sector.describe()
# Out:
#                count       mean       std   min   25%   50%   75%   max
# Sector
# Comercio       606.0  27.128713  6.736353   4.0  23.0  28.0  32.0  55.0
# Construcción    71.0  27.957746  6.810573  14.0  23.5  28.0  33.5  39.0
# Manufactura    302.0  27.903974  6.148283   7.0  24.0  28.0  32.0  45.0
# Servicios     1013.0  25.512340  6.672394   4.0  21.0  26.0  30.0  44.0

# %%
import plotly.graph_objects as go

labels = ['Comercio', 'Construcción', 'Manufactura', 'Servicios']
values = [Estres_sector_median[0], Estres_sector_median[1], Estres_sector_median[2], Estres_sector_median[3]]

fig = go.Figure(data=[go.Pie(labels=labels, values=values, hole=.40)])
fig.show()
# Out:
# <div>
#
#
#             <div id="b185096e-d848-4982-9a55-aee6afd0a1be" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b185096e-d848-4982-9a55-aee6afd0a1be")) {
#                     Plotly.newPlot(
#                         'b185096e-d848-4982-9a55-aee6afd0a1be',
#                         [{"hole": 0.4, "labels": ["Comercio", "Construcci\u00f3n", "Manufactura", "Servicios"], "type": "pie", "values": [28, 28, 28, 26]}],
# ...
