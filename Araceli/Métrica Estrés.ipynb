# %% [markdown]
# # Métrica Estrés

# %% [markdown]
# #### Estrés.-
# <div style="text-align: justify"> Estado de cansancio emocional y físico. Reacción del cuerpo ante un desafío o demanda. Y se requiere un cambio o adaptación. </div>
#
# #### Estresores.-
# <div style="text-align: justify"> Estímulos, condiciones o situaciones externas que generan una reacción de estrés. Y se requieren un cambio o adaptación. </div>
#
# #### Estresores Económicos.-
# <div style="text-align: justify"> Factores o situaciones relacionadas con el medio laboral y económico donde las personas dejen de sentir una estabilidad económica, por ejemplo despidos, inestabilidad laboral etc. </div>
#
# #### Niveles de estrés.-
#
# <div style="text-align: justify"> Se consideró al estrés como un concepto relevante en el presente trabajo debido a la situación por la que se está viviendo en estos días por la pandemia Covid-19. Se creyó pertinente dividir la frecuencia del estrés en una escala de cinco puntos del 0 al 4 basada en una prueba psicométrica, donde 0 representa una nula o menor cantidad de estrés y el cuatro se considera como gran cantidad de estrés. </div>
#
# <div style="text-align: justify"> Se decidió utilizar la frecuencia del 0 al 4 ya que se consideró que con ese rango se nos permite de manera más sencilla poder agrupar y categorizar las variables y de esta forma se puede obtener un resultado mucho más acertado y exacto.  </div>
#
# | 0                                                   | 1                                                   | 2                                                           | 3                                                               | 4                                            |
# |-----------------------------------------------------|-----------------------------------------------------|-------------------------------------------------------------|-----------------------------------------------------------------|----------------------------------------------|
# |<div style="text-align: left"> No se manifiesta <br>alguna respuesta <br>de estrés  </div>| <div style="text-align: left">Raramente se considera <br>como situación de estrés </div> | <div style="text-align: left"> En ocasiones/a veces <br>se considera estar <br>bajo estrés</div> | <div style="text-align: left">La respuesta de <br>estrés se considera <br>como algo frecuente</div> |<div style="text-align: left"> Se considera <br>estar bajo mucho <br>estrés</div> |
#
#
# #### Variables: Estresores Económicos
#
# <div style="text-align: justify"> A continuación se muestran las variables que se obtuvieron de la base de datos: “Diagnóstico de las Afectaciones Económicas a las Unidades Económicas de Jalisco por el Coronavirus” misma que se extrajo de encuestas enviadas por correo electrónico y contiene valiosa información de algunas empresas de Jalisco. </div>
#
# <div style="text-align: justify"> Las siguientes variables se consideraron como estresores económicos ya que engloban  situaciones relacionadas con el medio laboral y económico, en donde, en este caso, las empresas se vieron en la necesidad de afrontar ciertas pérdidas o cambios con respecto a su actividad económica. Tales como los despidos o pagos de salarios, situaciones que pueden llegar a causar estrés tomando en cuenta los estímulos y factores externos, en este caso se considera como factor externo la situación de la pandemia. </div>
#
# <div style="text-align: justify"> Las variables proporcionadas y clasificadas como estresores económicos nos brindan información y datos cualitativos, por lo que se propuso una escala, mencionada anteriormente, que se aplicó a cada variable y su naturaleza para que puedan ser cuantificables y así poder estimar la variable estrés por cada empresa que participó en esta encuesta. </div>
#
# <div style="text-align: justify"> La variable estrés al final será el valor resultante de la suma  de las variables seleccionadas y su escala que se detalla en el siguiente recuadro. Es importante recalcar que cuanto más alto sea ese valor más alto será el estrés de la empresa. </div>

# %% [markdown]
# <table border="1" width="100%" align="left">
#     <tr align="left">
#         <th style="text-align: justify" >Variable</th>
#         <th style="text-align: justify">Significado</th>
#         <th style="text-align: justify">Respuestas/Criterios</th>
#     </tr>
# <!-- Pérdidas porcentaje -->
#     <tr align="left">
#         <td style="text-align: justify">Pérdidas porcentaje</td>
#         <td style="text-align: justify" >¿Qué porcentaje cree que alcancen sus pérdidas como porcentaje de sus ventas?</td>
#         <td style="text-align: justify" >
#             <ul>
#                 <li>0-25%= 1</li>
#                 <li>25% a 50% = 2</li>
#                 <li>50% a 75%=3</li>
#                 <li>75% - 100% = 4</li>
#             </ul>
#             Proporcional: A mayor variación mayor estrés.<br>
#         </td>
#     </tr>
# <!-- Capacidad -->
#     <tr align="left">
#         <td style="text-align: justify">Capacidad</td>
#         <td style="text-align: justify" >¿Aproximadamente a qué porcentaje de capacidad se encuentra operando su establecimiento?</td>
#         <td style="text-align: justify" >
#             <ul>
#                 <li>0-25%= 1</li>
#                 <li>25% a 50% = 2</li>
#                 <li>50% a 75%=3</li>
#                 <li>75% - 100% = 4</li>
#             </ul>
#             Proporcional: A mayor variación mayor estrés.<br>
#         </td>
#     </tr>
# <!-- Cerrar -->
#     <tr align="left">
#         <td style="text-align: justify">Cerrar</td>
#         <td style="text-align: justify" >¿Ha considerado cerrar su establecimiento de manera definitiva?</td>
#         <td style="text-align: justify" >
#             <ul>
#                 <li>si = 2</li>
#                 <li>no=0</li>
#             </ul>
#             En el caso de no porque no lo ha considerado no hay un estrés, en el caso del si lo ha considerado pero no necesariamente cerrado por eso no es un nivel máximo de estrés.<br>
#         </td>
#     </tr>

# %%
#Importar Librerías 
import pandas as pd 
import numpy as np

# %% [markdown]
# ### Base de datos: IIEG_E_1

# %%
#Lectura de la base de datos
data=pd.read_excel('data.xlsx', sheet_name='IIEG_E_1') 
#Acomodo de datos
data = data.replace({"Más de 52": 52, "De 26 a 52": 26, "No aplica": 100, "No contesto": 101, "No sé":102, "Más de un año":12})
#Variable a predecir 
estres = np.zeros(len(data))

# %%
#ventas_porcentaje
for i in range(0, len(data)):
    if data['ventas_porcentaje'][i]>0 and data['ventas_porcentaje'][i]<=25:
        estres[i] += 1
    if data['ventas_porcentaje'][i]>25 and data['ventas_porcentaje'][i]<=50:
        estres[i] += 2
    if data['ventas_porcentaje'][i]>50 and data['ventas_porcentaje'][i]<=75:
        estres[i] += 3
    if data['ventas_porcentaje'][i]>75 and data['ventas_porcentaje'][i]<=100:
        estres[i] += 4
        
#perdidas_porcentaje
for i in range(0, len(data)):
    if data['perdidas_porcentaje'][i]>0 and data['perdidas_porcentaje'][i]<=25:
        estres[i] += 1
    if data['perdidas_porcentaje'][i]>25 and data['perdidas_porcentaje'][i]<=50:
        estres[i] += 2
    if data['perdidas_porcentaje'][i]>50 and data['perdidas_porcentaje'][i]<=75:
        estres[i] += 3
    if data['perdidas_porcentaje'][i]>75 and data['perdidas_porcentaje'][i]<=100:
        estres[i] += 4
        
#capacidad
for i in range(0, len(data)):
    if data['capacidad'][i]>0 and data['capacidad'][i]<=25:
        estres[i] += 1
    if data['capacidad'][i]>25 and data['capacidad'][i]<=50:
        estres[i] += 2
    if data['capacidad'][i]>50 and data['capacidad'][i]<=75:
        estres[i] += 3
    if data['capacidad'][i]>75 and data['capacidad'][i]<=100:
        estres[i] += 4
        
#cerrar
for i in range(0, len(data)):
    if data['cerrar'][i] == 'Sí':
        estres[i] += 2
    if data['cerrar'][i] == 'No':
        estres[i] += 0
        
#despidos
for i in range(0, len(data)):
    if data['despidos'][i] == 'Sí' or data['despidos'][i] == 'No, pero lo está considerando':
        estres[i] += 2
    if data['despidos'][i] == 'No' or data['despidos'][i] == 'No cuenta con personal':
        estres[i] += 0
    if data['despidos'][i] == 'No, pero lo hará en los próximos días':
        estres[i] += 3
        
#plantilla_porcentaje
for i in range(0, len(data)):
    if data['plantilla_porcentaje'][i]>0 and data['plantilla_porcentaje'][i]<=25:
        estres[i] += 1
    if data['plantilla_porcentaje'][i]>25 and data['plantilla_porcentaje'][i]<=50:
        estres[i] += 2
    if data['plantilla_porcentaje'][i]>50 and data['plantilla_porcentaje'][i]<=75:
        estres[i] += 3
    if data['plantilla_porcentaje'][i]>75 and data['plantilla_porcentaje'][i]<=100:
        estres[i] += 4
        
#pago_salarios
for i in range(0, len(data)):
    if data['pago_salarios'][i] == 100 or data['pago_salarios'][i] == 101 or data['pago_salarios'][i] == 102:
        estres[i] += 0
    if data['pago_salarios'][i]>0 and data['pago_salarios'][i]<=6:
        estres[i] += 1
    if data['pago_salarios'][i]>6 and data['pago_salarios'][i]<=12:
        estres[i] += 2
    if data['pago_salarios'][i]>12 and data['pago_salarios'][i]<=18:
        estres[i] += 3
    if data['pago_salarios'][i]>18:
        estres[i] += 4
        
#pago_impuestos
for i in range(0, len(data)):
    if data['pago_impuestos'][i] == 100 or data['pago_impuestos'][i] == 101 or data['pago_impuestos'][i] == 102:
        estres[i] += 0
    if data['pago_impuestos'][i]>0 and data['pago_impuestos'][i]<=6:
        estres[i] += 1
    if data['pago_impuestos'][i]>6 and data['pago_impuestos'][i]<=12:
        estres[i] += 2
    if data['pago_impuestos'][i]>12 and data['pago_impuestos'][i]<=18:
        estres[i] += 3
    if data['pago_impuestos'][i]>18:
        estres[i] += 4
        
#pago_credito
for i in range(0, len(data)):
    if data['pago_creditos'][i] == 100 or data['pago_creditos'][i] == 101  or data['pago_creditos'][i] == 102:
        estres[i] += 0
    if data['pago_creditos'][i]>0 and data['pago_creditos'][i]<=6:
        estres[i] += 1
    if data['pago_creditos'][i]>6 and data['pago_creditos'][i]<=12:
        estres[i] += 2
    if data['pago_creditos'][i]>12 and data['pago_creditos'][i]<=18:
        estres[i] += 3
    if data['pago_creditos'][i]>18:
        estres[i] += 4
        
#pago_renta
for i in range(0, len(data)):
    if data['pago_renta'][i] == 100 or data['pago_renta'][i] == 101  or data['pago_renta'][i] == 102:
        estres[i] += 0
    if data['pago_renta'][i]>0 and data['pago_renta'][i]<=6:
        estres[i] += 1
    if data['pago_renta'][i]>6 and data['pago_renta'][i]<=12:
        estres[i] += 2
    if data['pago_renta'][i]>12 and data['pago_renta'][i]<=18:
        estres[i] += 3
    if data['pago_renta'][i]>18:
        estres[i] += 4
        
#pago_internet
for i in range(0, len(data)):
    if data['pago_internet'][i] == 100 or data['pago_internet'][i] == 101  or data['pago_internet'][i] == 102:
        estres[i] += 0
    if data['pago_internet'][i]>0 and data['pago_internet'][i]<=6:
        estres[i] += 1
    if data['pago_internet'][i]>6 and data['pago_internet'][i]<=12:
        estres[i] += 2
    if data['pago_internet'][i]>12 and data['pago_internet'][i]<=18:
        estres[i] += 3
    if data['pago_internet'][i]>18:
        estres[i] += 4
        
#pago_agua
for i in range(0, len(data)):
    if data['pago_agua'][i] == 100 or data['pago_agua'][i] == 101  or data['pago_agua'][i] == 102:
        estres[i] += 0
    if data['pago_agua'][i]>0 and data['pago_agua'][i]<=6:
        estres[i] += 1
    if data['pago_agua'][i]>6 and data['pago_agua'][i]<=12:
        estres[i] += 2
    if data['pago_agua'][i]>12 and data['pago_agua'][i]<=18:
        estres[i] += 3
    if data['pago_agua'][i]>18:
        estres[i] += 4

#pago_luz
for i in range(0, len(data)):
    if data['pago_luz'][i] == 100 or data['pago_luz'][i] == 101  or data['pago_luz'][i] == 102:
        estres[i] += 0
    if data['pago_luz'][i]>0 and data['pago_luz'][i]<=6:
        estres[i] += 1
    if data['pago_luz'][i]>6 and data['pago_luz'][i]<=12:
        estres[i] += 2
    if data['pago_luz'][i]>12 and data['pago_luz'][i]<=18:
        estres[i] += 3
    if data['pago_luz'][i]>18:
        estres[i] += 4

#pago_gas
for i in range(0, len(data)):
    if data['pago_gas'][i] == 100 or data['pago_gas'][i] == 101  or data['pago_gas'][i] == 102:
        estres[i] += 0
    if data['pago_gas'][i]>0 and data['pago_gas'][i]<=6:
        estres[i] += 1
    if data['pago_gas'][i]>6 and data['pago_gas'][i]<=12:
        estres[i] += 2
    if data['pago_gas'][i]>12 and data['pago_gas'][i]<=18:
        estres[i] += 3
    if data['pago_gas'][i]>18:
        estres[i] += 4
        
#duracion
for i in range(0, len(data)):
    if  data['duracion'][i] == 12 or data['duracion'][i] == 102:
        estres[i] += 0
    if data['duracion'][i]>0 and data['duracion'][i]<=6:
        estres[i] += 1
    if data['duracion'][i]>6 and data['duracion'][i]<=12:
        estres[i] += 2
    if data['duracion'][i]>12 and data['duracion'][i]<=18:
        estres[i] += 3
    if data['duracion'][i]>18:
        estres[i] += 4
        
#capacidad_pago
for i in range(0, len(data)):
    if data['capacidad_pago'][i] == 'Sí':
        estres[i] += 1
    if data['capacidad_pago'][i] == 'No':
        estres[i] += 2
    if data['capacidad_pago'][i] == 'No sé':
        estres[i] += 0

#credito
for i in range(0, len(data)):
    if data['credito'][i] == 'Sí':
        estres[i] += 2
    if data['credito'][i] == 'No':
        estres[i] += 0
        
#aumento_insumos
for i in range(0, len(data)):
    if data['aumento_insumos'][i] == 'Sí':
        estres[i] += 3
    if data['aumento_insumos'][i] == 'No':
        estres[i] += 0
        
#aumento_precios
for i in range(0, len(data)):
    if data['aumento_precios'][i] == 'Sí':
        estres[i] += 3
    if data['aumento_precios'][i] == 'No':
        estres[i] += 0
        
#escasez_insumos
for i in range(0, len(data)):
    if data['escasez_insumos'][i] == 'Sí':
        estres[i] += 3
    if data['escasez_insumos'][i] == 'No':
        estres[i] += 0
        
#aumento_tipocambio
for i in range(0, len(data)):
    if data['aumento_tipocambio'][i] == 'Sí':
        estres[i] += 4
    if data['aumento_tipocambio'][i] == 'No':
        estres[i] += 0

# %%
# Agregar la variable al DataFrame
data['Estrés'] = estres
#Pasar el dataframe a un documento de excel
data.to_excel('datos_estres_1.xlsx', sheet_name='estrés')

# %% [markdown]
# ### Base de datos: IIEG_E_2

# %%
#Lectura de la base de datos
data=pd.read_excel('data.xlsx', sheet_name='IIEG_E_2') 
#Acomodo de datos
data = data.replace({"Más de 52": 52, "De 26 a 52": 26, "No aplica": 100, "No contesto": 101, "No sé":102, "Más de un año":12})
#Variable a predecir 
estres = np.zeros(len(data))

# %%
#ventas_porcentaje
for i in range(0, len(data)):
    if data['ventas_porcentaje'][i]>0 and data['ventas_porcentaje'][i]<=25:
        estres[i] += 1
    if data['ventas_porcentaje'][i]>25 and data['ventas_porcentaje'][i]<=50:
        estres[i] += 2
    if data['ventas_porcentaje'][i]>50 and data['ventas_porcentaje'][i]<=75:
        estres[i] += 3
    if data['ventas_porcentaje'][i]>75 and data['ventas_porcentaje'][i]<=100:
        estres[i] += 4
        
#perdidas_porcentaje
for i in range(0, len(data)):
    if data['perdidas_porcentaje'][i]>0 and data['perdidas_porcentaje'][i]<=25:
        estres[i] += 1
    if data['perdidas_porcentaje'][i]>25 and data['perdidas_porcentaje'][i]<=50:
        estres[i] += 2
    if data['perdidas_porcentaje'][i]>50 and data['perdidas_porcentaje'][i]<=75:
        estres[i] += 3
    if data['perdidas_porcentaje'][i]>75 and data['perdidas_porcentaje'][i]<=100:
        estres[i] += 4
        
#capacidad
for i in range(0, len(data)):
    if data['capacidad'][i]>0 and data['capacidad'][i]<=25:
        estres[i] += 1
    if data['capacidad'][i]>25 and data['capacidad'][i]<=50:
        estres[i] += 2
    if data['capacidad'][i]>50 and data['capacidad'][i]<=75:
        estres[i] += 3
    if data['capacidad'][i]>75 and data['capacidad'][i]<=100:
        estres[i] += 4
        
#cerrar
for i in range(0, len(data)):
    if data['cerrar'][i] == 'Sí':
        estres[i] += 2
    if data['cerrar'][i] == 'No':
        estres[i] += 0
        
#despidos
for i in range(0, len(data)):
    if data['despidos'][i] == 'Sí' or data['despidos'][i] == 'No, pero lo está considerando':
        estres[i] += 2
    if data['despidos'][i] == 'No' or data['despidos'][i] == 'No cuenta con personal':
        estres[i] += 0
    if data['despidos'][i] == 'No, pero lo hará en los próximos días':
        estres[i] += 3
        
#plantilla_porcentaje
for i in range(0, len(data)):
    if data['plantilla_porcentaje_afectada'][i]>0 and data['plantilla_porcentaje_afectada'][i]<=25:
        estres[i] += 1
    if data['plantilla_porcentaje_afectada'][i]>25 and data['plantilla_porcentaje_afectada'][i]<=50:
        estres[i] += 2
    if data['plantilla_porcentaje_afectada'][i]>50 and data['plantilla_porcentaje_afectada'][i]<=75:
        estres[i] += 3
    if data['plantilla_porcentaje_afectada'][i]>75 and data['plantilla_porcentaje_afectada'][i]<=100:
        estres[i] += 4
        
#pago_salarios
for i in range(0, len(data)):
    if data['pago_salarios'][i] == 100 or data['pago_salarios'][i] == 101 or data['pago_salarios'][i] == 102:
        estres[i] += 0
    if int(data['pago_salarios'][i])>0 and int(data['pago_salarios'][i])<=6:
        estres[i] += 1
    if int(data['pago_salarios'][i])>6 and int(data['pago_salarios'][i])<=12:
        estres[i] += 2
    if int(data['pago_salarios'][i])>12 and int(data['pago_salarios'][i])<=18:
        estres[i] += 3
    if int(data['pago_salarios'][i])>18 and int(data['pago_salarios'][i])<=24:
        estres[i] += 4
        
#pago_impuestos
for i in range(0, len(data)):
    if data['pago_impuestos'][i] == 100 or data['pago_impuestos'][i] == 101 or data['pago_impuestos'][i] == 102:
        estres[i] += 0
    if int(data['pago_impuestos'][i])>0 and int(data['pago_impuestos'][i])<=6:
        estres[i] += 1
    if int(data['pago_impuestos'][i])>6 and int(data['pago_impuestos'][i])<=12:
        estres[i] += 2
    if int(data['pago_impuestos'][i])>12 and int(data['pago_impuestos'][i])<=18:
        estres[i] += 3
    if int(data['pago_impuestos'][i])>18 and int(data['pago_impuestos'][i])<=24:
        estres[i] += 4
        
#pago_credito
for i in range(0, len(data)):
    if data['pago_creditos'][i] == 100 or data['pago_creditos'][i] == 101  or data['pago_creditos'][i] == 102:
        estres[i] += 0
    if int(data['pago_creditos'][i])>0 and int(data['pago_creditos'][i])<=6:
        estres[i] += 1
    if int(data['pago_creditos'][i])>6 and int(data['pago_creditos'][i])<=12:
        estres[i] += 2
    if int(data['pago_creditos'][i])>12 and int(data['pago_creditos'][i])<=18:
        estres[i] += 3
    if int(data['pago_creditos'][i])>18 and int(data['pago_creditos'][i])<=24:
        estres[i] += 4
        
#pago_renta
for i in range(0, len(data)):
    if data['pago_renta'][i] == 100 or data['pago_renta'][i] == 101  or data['pago_renta'][i] == 102:
        estres[i] += 0
    if int(data['pago_renta'][i])>0 and int(data['pago_renta'][i])<=6:
        estres[i] += 1
    if int(data['pago_renta'][i])>6 and int(data['pago_renta'][i])<=12:
        estres[i] += 2
    if int(data['pago_renta'][i])>12 and int(data['pago_renta'][i])<=18:
        estres[i] += 3
    if int(data['pago_renta'][i])>18 and int(data['pago_renta'][i])<=24:
        estres[i] += 4
        
        
#pago_internet
for i in range(0, len(data)):
    if data['pago_internet'][i] == 100 or data['pago_internet'][i] == 101  or data['pago_internet'][i] == 102:
        estres[i] += 0
    if int(data['pago_internet'][i])>0 and int(data['pago_internet'][i])<=6:
        estres[i] += 1
    if int(data['pago_internet'][i])>6 and int(data['pago_internet'][i])<=12:
        estres[i] += 2
    if int(data['pago_internet'][i])>12 and int(data['pago_internet'][i])<=18:
        estres[i] += 3
    if int(data['pago_internet'][i])>18 and int(data['pago_internet'][i])<=24:
        estres[i] += 4
        
#pago_agua
for i in range(0, len(data)):
    if data['pago_agua'][i] == 100 or data['pago_agua'][i] == 101  or data['pago_agua'][i] == 102:
        estres[i] += 0
    if int(data['pago_agua'][i])>0 and int(data['pago_agua'][i])<=6:
        estres[i] += 1
    if int(data['pago_agua'][i])>6 and int(data['pago_agua'][i])<=12:
        estres[i] += 2
    if int(data['pago_agua'][i])>12 and int(data['pago_agua'][i])<=18:
        estres[i] += 3
    if int(data['pago_agua'][i])>18 and int(data['pago_agua'][i])<=24:
        estres[i] += 4
        
#pago_luz
for i in range(0, len(data)):
    if data['pago_luz'][i] == 100 or data['pago_luz'][i] == 101  or data['pago_luz'][i] == 102:
        estres[i] += 0
    if int(data['pago_luz'][i])>0 and int(data['pago_luz'][i])<=6:
        estres[i] += 1
    if int(data['pago_luz'][i])>6 and int(data['pago_luz'][i])<=12:
        estres[i] += 2
    if int(data['pago_luz'][i])>12 and int(data['pago_luz'][i])<=18:
        estres[i] += 3
    if int(data['pago_luz'][i])>18 and int(data['pago_luz'][i])<=24:
        estres[i] += 4
        
#pago_gas
for i in range(0, len(data)):
    if data['pago_gas'][i] == 100 or data['pago_gas'][i] == 101  or data['pago_gas'][i] == 102:
        estres[i] += 0
    if int(data['pago_gas'][i])>0 and int(data['pago_gas'][i])<=6:
        estres[i] += 1
    if int(data['pago_gas'][i])>6 and int(data['pago_gas'][i])<=12:
        estres[i] += 2
    if int(data['pago_gas'][i])>12 and int(data['pago_gas'][i])<=18:
        estres[i] += 3
    if int(data['pago_gas'][i])>18 and int(data['pago_gas'][i])<=24:
        estres[i] += 4
        
        
#duracion
for i in range(0, len(data)):
    if  data['duracion'][i] == 12 or data['duracion'][i] == 102:
        estres[i] += 0
    if int(data['duracion'][i])>0 and int(data['duracion'][i])<=6:
        estres[i] += 1
    if int(data['duracion'][i])>6 and int(data['duracion'][i])<=12:
        estres[i] += 2
    if int(data['duracion'][i])>12 and int(data['duracion'][i])<=18:
        estres[i] += 3
    if int(data['duracion'][i])>18 and int(data['duracion'][i])<=24:
        estres[i] += 4
        
#capacidad_pago
for i in range(0, len(data)):
    if data['capacidad_pago'][i] == 'Sí':
        estres[i] += 1
    if data['capacidad_pago'][i] == 'No':
        estres[i] += 2
    if data['capacidad_pago'][i] == 'No sé':
        estres[i] += 0

#credito
for i in range(0, len(data)):
    if data['credito'][i] == 'Sí':
        estres[i] += 2
    if data['credito'][i] == 'No':
        estres[i] += 0
        
#aumento_insumos
for i in range(0, len(data)):
    if data['aumento_insumos'][i] == 'Sí':
        estres[i] += 3
    if data['aumento_insumos'][i] == 'No':
        estres[i] += 0
        
#aumento_precios
for i in range(0, len(data)):
    if data['aumento_precios'][i] == 'Sí':
        estres[i] += 3
    if data['aumento_precios'][i] == 'No':
        estres[i] += 0
        
#escasez_insumos
for i in range(0, len(data)):
    if data['escasez_insumos'][i] == 'Sí':
        estres[i] += 3
    if data['escasez_insumos'][i] == 'No':
        estres[i] += 0
        
#aumento_tipocambio
for i in range(0, len(data)):
    if data['aumento_tipocambio'][i] == 'Sí':
        estres[i] += 4
    if data['aumento_tipocambio'][i] == 'No':
        estres[i] += 0

# %%
# Agregar la variable al DataFrame
data['Estrés'] = estres
#Pasar el dataframe a un documento de excel
data.to_excel('datos_estres_2.xlsx', sheet_name='estrés')
