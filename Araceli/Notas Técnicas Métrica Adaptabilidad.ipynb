# %% [markdown]
# <img style="float: right; margin: 0px 0px 15px 15px;"
#      src="logo.JPEG"
#      width="400px" height="200px" />
#
# # Notas técnicas
#
# ### - Métrica Adaptabilidad
#
# ### - Proyecto: Urban Lab
#
# ### - Última Modificación: Junio 2020

# %% [markdown]
# ### Problema

# %% [markdown]
# > <div style="text-align: justify">Debido a la situación de la pandemia muchas empresas, específicamente hablando de las MIPyMES comenzaron a  percibir cambios en sus sistemas productivos y en las dinámicas de consumo, por lo que tuvieron que emplear nuevos métodos y estrategias para adaptarse a las nuevas exigencias que surgieron debido a la contingencia. Hubo algunas otras empresas que tuvieron que llegar a medidas extremas como despedir gente o incluso cerrar sus negocios.</div>
#
# > <div style="text-align: justify">Es importante tomar en cuenta la variable adaptabilidad, debido a que es una respuesta que se da debido al estrés, es decir, la reacción de estrés a los estímulos externos muchas veces demanda una adaptación. Además la naturalidad de esta pandemia nos ha puesto a todos en una situación de nueva normalidad a la que es necesario adaptarse.</div>
#
# > <div style="text-align: justify">La capacidad de adaptación se verá reflejada dependiendo de las estrategias y soluciones que lleguen a utilizar las empresas para poder seguir en funcionamiento. Dicha variable permite poder comprender cómo las empresas estaban enfrentando la situación actual y qué tantas lograron desarrollar nuevas capacidades para poder adaptarse y no tener que llegar a cerrar. </div>

# %% [markdown]
# ### Criterio de Construcción de Variable

# %% [markdown]
# > <div style="text-align: justify"> Para poder elaborar esta variable se realizó una escala para poder medir y evaluar la adaptabilidad en las empresas.  Se decidió utilizar la frecuencia del 0 al 2 ya que se consideró que con ese rango se nos permite de manera más sencilla poder agrupar y categorizar las variables y de esta forma se puede obtener un resultado mucho más acertado y exacto. </div>
#
#
# |  0 |   1 |  2 |
# |---|---|---|
# |  Nada | Bajo  |  Adecuado |
#
#
# > <div style="text-align: justify">El siguiente paso fue clasificar las variables contenidas en la base de datos utilizada como estresores económicos cuando fuera el caso.</div>
#
# > <div style="text-align: justify">A continuación se muestran las variables que se obtuvieron de la base de datos: “Diagnóstico de las Afectaciones Económicas a las Unidades Económicas de Jalisco por el Coronavirus” misma que se extrajo de encuestas enviadas por correo electrónico y contiene valiosa información de algunas empresas de Jalisco.</div>
#
# > <div style="text-align: justify">Las siguientes variables entran dentro de la categoría de adaptabilidad ya que comprenden  situaciones en donde, en este caso, las empresas demuestran la capacidad que tienen o no de responder ante las situaciones generadas y/o causadas debido a la contingencia. </div>
#
# > <div style="text-align: justify">Las variables proporcionadas y clasificadas como adaptabilidad nos proporcionan información y datos cualitativos, por lo mismo se propuso una escala, mencionada anteriormente, que se aplicó a cada variable y su naturaleza para que puedan ser cuantificables y así poder estimar la variable de adaptabilidad por cada empresa que participó en esta encuesta.</div>
#
# > <div style="text-align: justify">La variable adaptabilidad al final será el valor resultante de la suma  de las variables seleccionadas y su escala que se detalla en el siguiente recuadro.</div>

# %% [markdown]
# <table border="1" width="100%" align="left">
#     <tr align="left">
#         <th style="text-align: justify" >Variable</th>
#         <th style="text-align: justify">Significado</th>
#         <th style="text-align: justify">Respuestas/Criterios</th>
#     </tr>
# <!-- Capacidad -->
#     <tr align="left">
#         <td style="text-align: justify">Capacidad</td>
#         <td style="text-align: justify" >¿Aproximadamente a qué porcentaje de capacidad se encuentra operando su establecimiento?</td>
#         <td style="text-align: justify" >
#             <ul>
#                 <li>0-25%= 1</li>
#                 <li>25%-50%= 1</li>
#                 <li>50%-75%= 2</li>
#                 <li>75%-100%= 2</li>
#             </ul>
#             Se considera que las dos más altas son adaptarse de manera positiva, las dos más bajas se considera negativo aunque con una adaptabilidad baja. <br>
#         </td>
#     </tr>
# <!-- Cerrar razón -->
#    <tr align="left">
#         <td style="text-align: justify">Cerrar razón</td>
#         <td style="text-align: justify" >¿Cuál considera sería la principal razón para cerrar su establecimiento?</td>
#         <td style="text-align: justify" >
#             <ul>
#                 <li>Depende del Turismo = 0</li>
#                 <li>Falta de fondos o liquidez = 1</li>
#                 <li>Gastos elevados = 1</li>
#                 <li>incertidumbre sobre la duración y la caída en ventas = 0</li>
#                 <li>Multas del gobierno de la emergencia sanitaria= 0</li>
#                 <li>No aplica = 0</li>
#                 <li>No contestó= 0</li>
#                 <li>Otro (por favor especifique)= 0</li>
#             </ul>
#             En general, ninguna se considerará adecuada debido a que pueden parecer “excusas solucionables”, las que tienen que se consideraron bajas es porque hubo baja adaptabilidad (Negatividad)
#  <br>
#         </td>
#     </tr>
# <!-- Despidos  -->
#    <tr align="left">
#         <td style="text-align: justify">Despidos </td>
#         <td style="text-align: justify" >¿Su establecimiento se ha visto en la necesidad de despedir personal?</td>
#         <td style="text-align: justify" >
#             <ul>
#                 <li>No = 2</li>
#                 <li>Si = 0</li>
#                 <li>No cuenta con personal = 0</li>
#                 <li>No, pero lo está considerando = 1</li>
#                 <li>No, pero lo hará en los próximos días = 0</li>
#             Se considera que se podrían haber implementado estrategias de rotación con sus empleados, o algún tipo de alternativa.
#  <br>
#         </td>
#     </tr>
# <!-- Pago Salarios-->
#    <tr align="left">
#         <td style="text-align: justify">Pago Salarios  </td>
#         <td style="text-align: justify" >Semanas cree que puedan soportar sus fondos esta situación provocada por el COVID-19 para no dejar de pagar salarios</td>
#         <td style="text-align: justify" >
#             <ul>
#                 <li>"No aplica" y "No contestó ” = 0 </li>
#                 <li>0 a 6 semanas = 1</li>
#                 <li>6 a 12 semanas = 1</li>
#                 <li>12 a 18 semanas = 2</li>
#                 <li>18 a 24 semanas o más = 2</li>
#            Se considera mayor adaptabilidad a los que pueden pagar más semanas, y menor a las que pueden pagar menos.<br>
#         </td>
#     </tr>
# <!-- Capacidad de Pago-->
#    <tr align="left">
#         <td style="text-align: justify">Capacidad de Pago  </td>
#         <td style="text-align: justify" >¿Su establecimiento tiene la capacidad de pagar salarios si se mantiene cerrada o con trabajo desde casa?</td>
#         <td style="text-align: justify" >
#             <ul>
#                 <li>Si = 2</li>
#                 <li>No = 0</li>
#                 <li>No sé = 1</li>
#     </tr>
# <!-- Acuerdo Laboral  -->
#    <tr align="left">
#         <td style="text-align: justify">Acuerdo Laboral </td>
#         <td style="text-align: justify" >¿Ha intentado llegar a un acuerdo con sus trabajadores para modificar las condiciones laborales para establecer montos de pagos de indemnización durante un periodo de suspensión de actividades?</td>
#         <td style="text-align: justify" >
#             <ul>
#                 <li>Si = 2</li>
#                 <li>No = 0</li>
#                 <li>No, pero lo está considerando = 1</li>
#                 <li>No, pero lo va a hacer en los próximos días = 1</li
#     </tr>
#  <!-- Trabajo en casa   -->
#    <tr align="left">
#         <td style="text-align: justify">Trabajo en casa </td>
#         <td style="text-align: justify" >¿Ha enviado a sus empleados a trabajar desde casa?</td>
#         <td style="text-align: justify" >
#             <ul>
#                 <li>Si = 2</li>
#                 <li>No = 0</li>
#                 <li>No, pero lo está considerando = 1</li>
#                 <li>No, pero lo va a hacer en los próximos días = 1</li
#     </tr>
# <!-- Trabajo en casa motivo   -->
#    <tr align="left">
#         <td style="text-align: justify">Trabajo en casa motivo</td>
#         <td style="text-align: justify" >¿Por qué no enviará a sus empleados a trabajar desde casa?</td>
#         <td style="text-align: justify" >
#             <ul>
#                 <li>La naturaleza de mi negocio no lo permite =1</li>
#                 <li>No aplica = 0</li>
#                 <li>No contestó =0</li>
#                 <li>No me convence la modalidad = 0</li>
#                 <li>Porque se considera una actividad esencial para la emergencia =1</li>
#                 <li>otro (por favor especifique) =0</li>
#        </tr>
# <!-- Aumento de precios   -->
#    <tr align="left">
#         <td style="text-align: justify">Trabajo en casa motivo</td>
#         <td style="text-align: justify" >¿Ha tenido que subir precios para compensar mayores costos?</td>
#         <td style="text-align: justify" >
#             <ul>
#                 <li>Si = 2 </li>
#                 <li>No = 2</li>
#     </tr>
# </table>

# %% [markdown]
# ### Construcción de variable

# %%
#Importar Librerías 
import pandas as pd 
import numpy as np

# %% [markdown]
# ### Base de datos: IIEG_E_1

# %%
#Lectura de la base de datos
data=pd.read_excel('data.xlsx', sheet_name='IIEG_E_1') 
#Acomodo de datos
data = data.replace({"Más de 52": 52, "De 26 a 52": int(26), "No aplica": int(100), "No contesto": int(101), "No sé":int(102), "Más de un año":int(12)})
#Variable a predecir 
adaptabilidad = np.zeros(len(data))

# %%
#capacidad
for i in range(0, len(data)):
    if data['capacidad'][i]>0 and data['capacidad'][i]<=25:
        adaptabilidad[i] += 1
    if data['capacidad'][i]>25 and data['capacidad'][i]<=50:
        adaptabilidad[i] += 1
    if data['capacidad'][i]>50 and data['capacidad'][i]<=75:
        adaptabilidad[i] += 2
    if data['capacidad'][i]>75 and data['capacidad'][i]<=100:
        adaptabilidad[i] += 2
        
#cerrar_razon
for i in range(0, len(data)):
    if data['cerrar_razon'][i] == 'Falta de fondos o liquidez' or data['cerrar_razon'][i] == 'Gastos elevados' \
        or data['cerrar_razon'][i] == 'Problemas con importación' or data['cerrar_razon'][i] == 'Problemas de cobranza':
        adaptabilidad[i] += 1
    else:
        adaptabilidad[i] += 0

#despidos
for i in range(0, len(data)):
    if data['despidos'][i] == 'Sí' or data['despidos'][i] == 'No cuenta con personal'\
    or data['despidos'][i] == 'No, pero lo hará en los próximos días':
        adaptabilidad[i] += 0
    if data['despidos'][i] == 'No':
        adaptabilidad[i] += 2
    if data['despidos'][i] == 'No, pero lo está considerando':
        adaptabilidad[i] += 1

#pago_salarios
for i in range(0, len(data)):
    if data['pago_salarios'][i] == 100 or data['pago_salarios'][i] == 101 or data['pago_salarios'][i] == 102:
        adaptabilidad[i] += 0
    if data['pago_salarios'][i]>0 and data['pago_salarios'][i]<=6:
        adaptabilidad[i] += 1
    if data['pago_salarios'][i]>6 and data['pago_salarios'][i]<=12:
        adaptabilidad[i] += 1
    if data['pago_salarios'][i]>12 and data['pago_salarios'][i]<=18:
        adaptabilidad[i] += 2
    if data['pago_salarios'][i]>18 and data['pago_salarios'][i]<=24:
        adaptabilidad[i] += 2

#capacidad_pago
for i in range(0, len(data)):
    if data['capacidad_pago'][i] == 'Sí':
        adaptabilidad[i] += 2
    if data['capacidad_pago'][i] == 'No':
        adaptabilidad[i] += 0
    if data['capacidad_pago'][i] == 'No sé':
        adaptabilidad[i] += 1
        
#acuerdo_laboral
for i in range(0, len(data)):
    if data['acuerdo_laboral'][i] == 'No, pero lo está considerando' \
    or data['despidos'][i] == 'No, pero lo va a hacer en los próximos días':
        adaptabilidad[i] += 1
    if data['acuerdo_laboral'][i] == 'Sí':
        adaptabilidad[i] += 2
    if data['acuerdo_laboral'][i] == 'No':
        adaptabilidad[i] += 0
        
#trabajo_casa
for i in range(0, len(data)):
    if data['trabajo_casa'][i] == 'No, pero lo está considerando' \
    or data['despidos'][i] == 'No, pero lo va a hacer en los próximos días':
        adaptabilidad[i] += 1
    if data['trabajo_casa'][i] == 'Sí':
        adaptabilidad[i] += 2
    if data['trabajo_casa'][i] == 'No':
        adaptabilidad[i] += 0
        
#trabajo_casa_motivo
for i in range(0, len(data)):
    if data['trabajo_casa_motivo'][i] == 'La naturaleza de mi negocio no lo permite' \
    or data['trabajo_casa_motivo'][i] == 'Porque se considera una actividad esencial para la emergencia':
        adaptabilidad[i] += 1
    else:
        adaptabilidad[i] += 0

#aumento_precios
for i in range(0, len(data)):
    if data['aumento_precios'][i] == 'Sí':
        adaptabilidad[i] += 2
    if data['aumento_precios'][i] == 'No':
        adaptabilidad[i] += 2

# %% [markdown]
# ### Resultados
#
# > El resultado es la misma base de datos con la nueva columna que contiene el valor del estrés para cada empresa.

# %%
# Agregar la variable al DataFrame
data['Adaptabilidad'] = adaptabilidad

data
# Out:
#       Folio         ID Levantada por        Municipio       CP        Sector  \
# 0         1  208841844          IIEG      Tlaquepaque  45608.0      Comercio
# 1         2  208843594          IIEG      Guadalajara  44630.0  Construcción
# 2         3  208844050          IIEG  Puerto Vallarta  48333.0   Manufactura
# 3         5  208844264          IIEG      Guadalajara  44890.0      Comercio
# 4         7  208845188          IIEG  Lagos de Moreno  47420.0     Servicios
# ...     ...        ...           ...              ...      ...           ...
# 1987   1951  209032456         CUCEA  Lagos de Moreno  48460.0      Comercio
# 1988   1955  209032595         CUCEA  Lagos de Moreno  47480.0  Construcción
# 1989   1961  209032863          IIEG      Guadalajara  44360.0      Comercio
# 1990   1963  209032983         CUCEA  Lagos de Moreno  47470.0     Servicios
# 1991   1987  209045096          IIEG      Guadalajara  44160.0     Servicios
#
# ...

# %%
#Pasar el dataframe a un documento de excel
data.to_excel('datos_adaptabilidad_1.xlsx', sheet_name='Adaptabilidad')

# %% [markdown]
# ### Citas

# %% [markdown]
# > Instituto de Información Estadística y Geográfica de Jalisco. (2020). Base de datos Diagnóstico de las Afectaciones Económicas a las Unidades Económicas de Jalisco por el Coronavirus. [IIEG].
